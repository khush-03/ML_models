# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_excel(r'C:\Users\khush\Downloads\test.xlsx')

# %%
df.isnull()
# Out:
#           T1     T2     T3     T4     T5     T6     T7     T8     T9    T10  \
# 0      False  False  False  False  False  False  False  False  False  False
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 15747  False  False  False  False  False  False  False  False  False  False
# 15748  False  False  False  False  False  False  False  False  False  False
# 15749  False  False  False  False  False  False  False  False  False  False
# 15750  False  False  False  False  False  False  False  False  False  False
# 15751  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

# %%
num_clusters = 3
kmeans = KMeans(n_clusters=num_clusters, random_state=42)
kmeans.fit(scaled_data)
clusters = kmeans.labels_
df['cluster'] = clusters

# %%
def predict_cluster(data_point):
    scaled_point = scaler.transform([data_point])
    cluster = kmeans.predict(scaled_point)
    return cluster[0]

# %%
def explain_cluster(data_point):
    scaled_point = scaler.transform([data_point])
    distances = kmeans.transform(scaled_point)
    cluster = kmeans.predict(scaled_point)[0]
    return f"The data point is closest to cluster {cluster} with distances to centroids: {distances[0]}"

# %%
data_point = df.iloc[0, :-1].values
predicted_cluster = predict_cluster(data_point)
print(f"The new data point belongs to cluster: {predicted_cluster}")
print(explain_cluster(data_point))
# Out:
# The new data point belongs to cluster: 1
# The data point is closest to cluster 1 with distances to centroids: [6.13328735 3.98767649 6.53740693]
# C:\Users\khush\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# C:\Users\khush\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
